# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardosantosugb/PROGRAIII-SEMI-2025/blob/main/introduccion_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola mundo")
print("Bienvenidos a la clase de programacion computaciona lll")
# Out:
# hola mundo
# Bienvenidos a la clase de programacion computaciona lll

# %%
nombre = "Eduardo Santos"
edad = "18"
print(nombre, edad)
# Out:
# Eduardo Santos 18

# %%
num1 = 5
num2 = 8.9
suma = num1 + num2
print("la suma es: ", suma)
# Out:
# la suma es:  13.9

# %%
num1 = float(input("num1:"))
num2 = float(input("num2:"))
suma = num1+ num2
print("la suma es: ", suma)
# Out:
# num1:4
# num2:4
# la suma es:  8.0

# %%
num1 = float(input("num1:"))
num2 = float(input("num2:"))
resta = num1- num2
print("la resta es: ", resta)
# Out:
# num1:8
# num2:4
# la resta es:  4.0
